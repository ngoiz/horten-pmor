# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 100
mpl.rcParams['figure.figsize'] = (8, 6)
# %config InlineBackend.figure_format = 'retina'

# %%
eig_data = np.loadtxt('./source/results/velocity_eigenvalues.txt')

# %%
interp_data = np.loadtxt('./results/velocity_eigenvalues.txt')

# %%
plt.scatter(eig_data[:, 1] / 2/ np.pi, eig_data[:, 2]/2/np.pi, c=eig_data[:, 0], cmap='copper')
plt.scatter(interp_data[:, 1] / 2/ np.pi, interp_data[:, 2]/2/np.pi, c=interp_data[:, 0], cmap='Blues', marker='+')


plt.xlim(-10, 2)
plt.ylim(-0.5, 10)
plt.grid()
